# %% [markdown]
# # Лаборатораня работа №1
# ## Выполнил студент группы БСТ1901 Фролов Андрей
# ### Задание 1

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание 2

# %%
import random

def matrix(m=50, n=50, min_limit=-250, max_limit=1000):
    return[[random.randint(min_limit, max_limit) for j in range(n)] for i in range(m)]

matrix = matrix(m=100, n=100)
print(matrix)
# Out:
# [[-191, -50, 304, 346, -250, 152, 410, 502, -180, 943, 140, 255, 220, -86, 935, 730, 565, -42, 448, 570, 113, -180, 11, 59, 966, 802, 787, 254, 419, 540, 331, 529, 857, 847, 236, -239, 631, 954, 565, 260, -74, 813, 987, -213, 51, 228, -111, -241, 374, 443, 128, 809, -220, -113, 539, 669, -59, 849, 282, -60, 683, 691, -126, 563, 792, -186, 531, 176, 20, -147, -123, 428, 301, -245, 983, -2, 297, -62, -209, 434, 201, -51, 579, 163, 233, 249, -243, 216, -206, 873, 421, -147, 583, 618, 325, -86, 201, 778, 624, 536], [777, 675, 37, 424, 880, 599, 307, 878, -19, 43, 90, 735, 248, 7, 917, 523, 273, 625, 357, -80, -243, 831, 366, 880, 339, 715, 571, -73, 210, 724, 62, 901, 720, 960, 633, -158, 820, 336, 638, 740, 709, 478, 696, 901, 816, 701, 768, 671, -138, 576, 708, 353, 885, -243, 351, -141, 10, 914, 810, 963, 107, 797, -181, 399, 860, -128, -2, 522, 479, 915, 702, 273, 601, -59, -35, -250, 937, 919, -102, 539, 701, 473, 167, 670, 990, 395, 757, 448, 508, 208, 562, -99, 790, 809, 974, 907, -175, 917, -160, 750], [-213, 572, -121, 702, 52, 59, -50, 920, -45, 373, 975, -125, 413, 821, 516, 292, 129, 916, -113, 952, 280, 236, 877, 936, 750, 352, 482, 329, 788, 693, 684, 972, 235, -229, 338, 195, 75, 942, 269, 899, 818, 412, 538, 677, -207, 399, 428, 495, 149, 70, 251, -227, 210, 955, 734, 988, 92, 302, 896, 18, -140, 946, 360, 75, -207, 989, 115, 122, 766, 762, -142, -91, 519, 794, 150, 936, 805, -140, 132, -113, 604, 332, -162, 933, 145, 400, 618, 839, 549, 892, 847, 259, -133, 361, 752, 331, 87, 312, 61, 130], [262, -75, 577, -146, -89, 563, 181, 854, 381, 857, 344, 84, 608, 263, 207, 52, 47, 101, 709, 705, -58, 533, 183, 317, -7, 208, 670, -46, 719, 587, 26, 106, 868, 188, 675, 667, 536, 833, 646, 841, 95, 682, 438, 673, 869, 675, 84, 82, 615, 939, 208, -196, 756, 256, 638, 410, -151, 461, 4, 514, 947, 899, 577, 629, 990, 696, 579, 927, 187, 744, 80, 355, 71, 270, 928, 30
            mn = min(range(i, len(row)), key=row.__getitem__)
            row[i], row[mn] = row[mn], e
    return data

start = time.perf_counter()
selection(matrix)
sort_time = time.perf_counter() - start
print(f"Сортировка выбором {sort_time}")

def insertion_sort(arr):
    for row in arr:
        for i in range(1, len(row)):
            key = row[i]
            j = i-1
            while j >=0 and key < row[j] :
                row[j+1] = row[j]
                j -= 1
            row[j+1] = key 
    return arr

start = time.perf_counter()
insertion_sort(matrix)
sort_time = time.perf_counter() - start
print(f"Сортировка вставкой {sort_time}")

def bSort(array):
    length = len(array)
    for i in range(length):
        for j in range(0, length-i-1):
            if array[j] > array[j+1]:
                temp = array[j]
                array[j] = array[j+1]
                array[j+1] = temp
    return array
                
start = time.perf_counter()
bSort(matrix)
sort_time = time.perf_counter() - start
print(f"Сортировка обменом {sort_time}")

def shell_sort(data):
    last_index = len(data) - 1
    step = len(data)//2
    while step > 0:
        for i in range(step, last_index + 1, 1):
            j = i
            delta = j - step
            while delta >= 0 and data[delta] > data[j]:
                data[delta], data[j] = data[j], data[delta]
                j = delta
                delta = j - step
        step //= 2
    return data

start = time.perf_counter()
shell_sort(matrix)
sort_time = time.perf_counter() - start
print(f"Сортировка Шелла {sort_time}")

def quicksort(nums):
   if len(nums) <= 1:
       return nums
   else:
       q = random.choice(nums)
       s_nums = []
       m_nums = []
       e_nums = []
       for n in nums:
           if n < q:
               s_nums.append(n)
           elif n > q:
               m_nums.append(n)
           else:
               e_nums.append(n)
       return quicksort(s_nums) + e_nums + quicksort(m_nums)

start = time.perf_counter()
quicksort(matrix)
sort_time = time.perf_counter() - start
print(f"Быстрая сортировка {sort_time}")

def heapify(nums, heap_size, root_index):  
    largest = root_index
    left_child = (2 * root_index) + 1
    right_child = (2 * root_index) + 2

    if left_child < heap_size and nums[left_child] > nums[largest]:
        largest = left_child

    if right_child < heap_size and nums[right_child] > nums[largest]:
        largest = right_child

    if largest != root_index:
        nums[root_index], nums[largest] = nums[largest], nums[root_index]
        heapify(nums, heap_size, largest)

def heap_sort(nums):  
    n = len(nums)

    for i in range(n, -1, -1):
        heapify(nums, n, i)

    for i in range(n - 1, 0, -1):
        nums[i], nums[0] = nums[0], nums[i]
        heapify(nums, i, 0)
    
start = time.perf_counter()
heap_sort(matrix)
sort_time = time.perf_counter() - start
print(f"Пирамидальная сортировка {sort_time}")
# Out:
# Сортировка выбором 0.044046699999853445
# Сортировка вставкой 0.003887599999870872
# Сортировка обменом 0.0014435000002777088
# Сортировка Шелла 0.00036550000004353933
# Быстрая сортировка 0.0009456999996473314
# Пирамидальная сортировка 0.0011533000001691107
